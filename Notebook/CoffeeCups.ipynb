# %%
import numpy as np

class CoffeeCups:
    
    def __init__(self, path = "./Data/Coffee/BD_MapaPerfilesTazaRisaralda_ciat.csv"):
        
        
        self.path = path
        
        # Reading file
        records_matrix = open(self.path)
        # Reading the data 
        tmpMatriceData =  [l.strip().split(';') for l in records_matrix.readlines()[2::]]
        records_matrix.seek(0)
        tmpMatriceInfo =  [l.strip().split(';') for l in records_matrix.readlines()[:1]]
        self.matriceData = np.array(tmpMatriceData)
        self.matriceInfo = np.array(tmpMatriceInfo)
        
        self.codes = {}
        for i in range(len(self.matriceData)):
            tmp = {str(self.matriceData[i,0]) : i}
            self.codes.update(tmp)
        
        self.infoTastePoints = ["Fragrance-Aroma","Savor","Savor residual","Body","Acidity","Balance","Sweetness","Clean-cup","Uniformity","Taster points","Total"]
    #======================================================================
    # Culture informations: 
    # Return the informations below:
    # - Returns the table ID of the cup (index in matriceData)
    # - Returns the codes of all cups
    # - Returns the date of tasting
    # - Returns the taster name/entity
    # - Returns the Productor name
    # - Returns the Licence number
    # - Returns the SICA ID
    # - Returns the Property name
    # - Returns the Verada name
    # - Returns the Total SCA points
    # - Returns a summary of all those informations
    #
    #======================================================================
        
        
    # returns the index in matriceData of the requested cupCode
    def getTableID(self, cupCode):
        return self.codes[cupCode]
    
    # returns the list of all cup's codes
    def getCodes(self):
        return self.codes.keys()
    
    # Returns Date in np.string_ format
    def getDate(self, cupCode):
        return self.matriceData[self.codes[cupCode], 1]
    
    def getTaster(self, cupCode):
        return self.matriceData[self.codes[cupCode], 2]
    
    def getProductorName(self, cupCode):
        return self.matriceData[self.codes[cupCode], 3]
    
    # Cédula ?
    def getLicence(self, cupCode):
        return self.matriceData[self.codes[cupCode], 4]
    
    def getSICA(self, cupCode):
        return self.matriceData[self.codes[cupCode], 5]
    
    # Finca
    def getProperty(self, cupCode):
        return self.matriceData[self.codes[cupCode], 6]
    
    # Vereda
    def getVereda(self, cupCode):
        return self.matriceData[self.codes[cupCode], 7]
    

    
    
    def getCultureSummary(self, cupCode):
        summary = []
        
        summary.append(self.getDate(cupCode))
        summary.append(self.getTaster(cupCode))
        summary.append(self.getProductorName(cupCode))
        summary.append(self.getLicence(cupCode))
        summary.append(self.getSICA(cupCode))
        summary.append(self.getProperty(cupCode))
        summary.append(self.getVereda(cupCode))
        
        return summary
    
    
    
    #======================================================================
    # Taste informations: 
    # Return the textual values of the tastes
    #
    #======================================================================
    # returns trimed / separated notes (text) of different traits of coffee taste
    # For encoding test others .decode('iso-8859-1') works but bad
    
    def getTasteData(self, cupCode, index):
        tmp = self.matriceData[self.codes[cupCode], index]
        trimed = []
        trimed[:] = [f.strip() for f in tmp.split(",")]
        return trimed
    
    def getFragranceAromaNota(self, cupCode):
        return self.getTasteData(cupCode, 10)
    
    def getSavorNota(self, cupCode):
        return self.getTasteData(cupCode, 12)
    
    def getSavorResidualNota(self, cupCode):
        return self.getTasteData(cupCode, 14)
    
    def getBodyNota(self, cupCode):
        return self.getTasteData(cupCode, 16)
    
    def getAcidityNota(self, cupCode):
        return self.getTasteData(cupCode, 18)
    
    def getBalanceNota(self, cupCode):
        return self.getTasteData(cupCode, 20)
    
    def getSweetnessNota(self, cupCode):
        return self.getTasteData(cupCode, 22)
    
    def getCleancupNota(self, cupCode):
        return self.getTasteData(cupCode, 24)
    
    def getUniformityNota(self, cupCode):
        return self.getTasteData(cupCode, 26)
    
    def getTasteNoteSummary(self, cupCode):
        
        summary = []
        
        summary.append(self.getFragranceAromaNota(cupCode))
        summary.append(self.getSavorNota(cupCode))
        summary.append(self.getSavorResidualNota(cupCode))
        summary.append(self.getBodyNota(cupCode))
        summary.append(self.getAcidityNota(cupCode))
        summary.append(self.getBalanceNota(cupCode))
        summary.append(self.getSweetnessNota(cupCode))
        summary.append(self.getCleancupNota(cupCode))
        summary.append(self.getUniformityNota(cupCode))
        
        return summary
    
    #======================================================================
    # Taste informations: 
    # Return the number of Points of each note
    #
    #======================================================================
    
    def getTastePoints(self, cupCode, index):
        tmp = str(self.matriceData[self.codes[cupCode], index])
        if tmp == "":
            return None
        tmp = tmp.replace(",", ".")
        #print tmp
        try:
            return float(tmp)
        except:
            #[DEBUG] 
            #print("Cup code: ", cupCode,  "Data format problem. Data: ", tmp)
            return None
    
    def getTotalSCAPoints(self, cupCode):
        return self.getTastePoints(cupCode, 8)
    
    def getFragranceAromaPoints(self, cupCode):
        return self.getTastePoints(cupCode, 9)
    
    def getSavorPoints(self, cupCode):
        return self.getTastePoints(cupCode, 11)
    
    def getSavorResidualPoints(self, cupCode):
        return self.getTastePoints(cupCode, 13)
    
    def getBodyPoints(self, cupCode):
        return self.getTastePoints(cupCode, 15)
    
    def getAcidityPoints(self, cupCode):
        return self.getTastePoints(cupCode, 17)
    
    def getBalancePoints(self, cupCode):
        return self.getTastePoints(cupCode, 19)
    
    def getSweetnessPoints(self, cupCode):
        return self.getTastePoints(cupCode, 21)
    
    def getCleancupPoints(self, cupCode):
        return self.getTastePoints(cupCode, 23)
    
    def getUniformityPoints(self, cupCode):
        return self.getTastePoints(cupCode, 25)
    
    def getTasterPoints(self, cupCode):
        return self.getTastePoints(cupCode, 27)
    
    def getTastePointsSummary(self, cupCode):
        
        summary = []
        
        summary.append(self.getFragranceAromaPoints(cupCode))
        summary.append(self.getSavorPoints(cupCode))
        summary.append(self.getSavorResidualPoints(cupCode))
        summary.append(self.getBodyPoints(cupCode))
        summary.append(self.getAcidityPoints(cupCode))
        summary.append(self.getBalancePoints(cupCode))
        summary.append(self.getSweetnessPoints(cupCode))
        summary.append(self.getCleancupPoints(cupCode))
        summary.append(self.getUniformityPoints(cupCode))
        summary.append(self.getTasterPoints(cupCode))
        summary.append(self.getTotalSCAPoints(cupCode))
        
        return summary
    
    # TODO - Geocode Vereda if possible

# %%
import numpy as np

class CoffeeCup:
    def __init__(self, code):
        cc = CoffeeCups()
        self.code = code
        self.info = cc.getCultureSummary(code)
        self.taste = cc.getTasteNoteSummary(code)
        self.points = cc.getTastePointsSummary(code)
        self.infoTastePoints = cc.infoTastePoints
        self.totalPoints = cc.getTotalSCAPoints(code)

# %%
coffee = CoffeeCups()

#print coffee.matriceData
#print coffee.codes
#print coffee.getCodes()
#print coffee.getTableID('1701')
#print coffee.getDate('1701')
#print coffee.getTaster('1701')
#print coffee.getProductorName('1701')
#print coffee.getLicence('1701')
#print coffee.getSICA('1701')
#print coffee.getProperty('1701')
#print coffee.getVereda('1701')
#print("\n")
#print coffee.getCultureSummary('1701')

#print coffee.getFragranceAromaNota('1701')
#print coffee.getSavorNota('1701')
#print coffee.getBodyNota('1701')
#print coffee.getAcidityNota('1701')
#print coffee.getBalanceNota('1701')
#print coffee.getSweetnessNota('1701')
#print coffee.getCleancupNota('1701')
#print coffee.getUniformityNota('1701')

#print("\nCoffee informations")
#print coffee.getCultureSummary('1701')
#print coffee.getTasteNoteSummary('1701')
#print coffee.getTastePointsSummary('1701')

#print("\nCoffee informations")
#print coffee.getCultureSummary('1702')
#print coffee.getTasteNoteSummary('1702')
#print coffee.getTastePointsSummary('1702')

#print("\nCoffee informations")
#print coffee.getCultureSummary('1703')
#print coffee.getTasteNoteSummary('1703')
#print coffee.getTastePointsSummary('1703')

allCups = []

for cupCode in coffee.getCodes():
    allCups.append(CoffeeCup(cupCode))

for cup in allCups:
    print cup.points

for cup in allCups:
    print cup.code
    
for cup in allCups:
    print cup.info
# Out:
# [None, None, None, None, None, None, None, None, None, None, 73.0]
# [None, None, None, None, None, None, None, None, None, None, 81.25]
# [None, None, None, None, None, None, None, None, None, None, 52.5]
# [None, None, None, None, None, None, None, None, None, None, 79.0]
# [None, None, None, None, None, None, None, None, None, None, 83.0]
# [None, None, None, None, None, None, None, None, None, None, 86.0]
# [None, None, None, None, None, None, None, None, None, None, 68.0]
# [None, None, None, None, None, None, None, None, None, None, 78.0]
# [None, None, None, None, None, None, None, None, None, None, 79.0]
# [None, None, None, None, None, None, None, None, None, None, 84.0]
# [None, None, None, None, None, None, None, None, None, None, 79.0]
# [None, None, None, None, None, None, None, None, None, None, 75.0]
# [None, None, None, None, None, None, None, None, None, None, 83.5]
# [None, None, None, None, None, None, None, None, None, None, 82.75]
# [None, None, None, None, None, None, None, None, None, None, 82.0]
# [None, None, None, None, None, None, None, None, None, None, 70.0]
# [None, None, None, None, None, None, None, None, None, None, 79.0]
# [None, None, None, None, None, None, None, None, None, None, 79.0]
# [None, None, None, None, None, None, None, None, None, None, 84.0]
# [None, None, None, None, None, None, None, None, None, None, 78.5]
# [None, None, None, None, None, None, None, None, None, None, 82.5]
# [None, None, None, None, None, None, None, None, None, None, 58.5]
# [None, None, None, None, None, None, None, None, None, None, 60.0]
# [None, None, None, None, None, None, None, None, None, None, 83.5]
# [None, None, None, None, None, None, None, None, None, None, 76.0]
# [None, None, None, None, None, None, None, None, None, None, 67.0]
# [None, None, None, None, None, None, None, None, None, None, 84.5]
# [None, None, None, None, None, None, None, None, None, None, 81.0]
# [None, None, None, None, None, None, None, None, None, None, 85.25]
# [None, None, None, None, None, None, None, None, None, None, 79.0]
# [None, None, None, None, None, None, None, None, None, None, 84.25]
# [None, None, None, None, None, None, None, None, None, None, 50.0]
# [None, None, None, None, None, None, None, None, None, None, 80.5]
# [None, None, None, None, None, None, None, None, None, None, 85.25]
# [None, None, None, None, None, None, None, None, None, None, 82.0]
# [None, None, None, None, None, None, None, None, None, None, 83.0]
# [None, None, None, None, None, None, None, None, None, None, 79.0]
# [None, None, None, None, None, None, None, None, None, None, 53.0]
# [None, None, None, None, None, None, None, None, None, None, 84.5]
# [None, None, None, None, None, None, None, None, None, None, 76.0]
# [None, None, None, None, None, None, None, None, None, None, 79.0]
# [None, None, None, None, None, None, None, None, None, None, 85.25]
# [None, None, None, None, None, None, None, None, None, None, 83.0]
# [None, None, None, None, None, None, None, None, None, None, 77.0]
# [None, None, None, None, None, None, None, None, None, None, 72.0]
# [None, None, None, None, None, None, None, None, None, None, 84.0]
# [None, None, None, None, None, None, None, None, None, None, 53.0]
# [5.0, 6.25, 6.0, 6.0, 6.0, 5.0, 10.0, 10.0, 10.0, 6.0, 70.25]
# [8.0, 8.0, 7.75, 8.0, 8.0, 8.0, 10.0, 10.0, 10.0, 8.0, 85.75]
# [7.5, 7.0, 7.0, 7.5, 7.5, 7.5, 10.0, 10.0, 10.0, 7.0, 81.0]
# [None, None, None, None, None, None, None, None, None, None, 87.0]
# [None, None, None, None, None, None, None, None, None, None, 83.5]
# [None, None, None, None, None, None, None, None, None, None, 81.25]
# [None, None, None, None, None, None, None, None, None, None, 83.5]
# [None, None, None, None, None, None, None, None, None, None, 84.0]
# [None, None, None, None, None, None, None, None, None, None, 80.5]
# [None, None, None, None, None, None, None, None, None, None, 68.0]
# [None, None, None, None, None, None, None, None, None, None, 83.0]
# [None, None, None, None, None, None, None, None, None, None, 85.0]
# [None, None, None, None, None, None, None, None, None, None, 86.5]
# [None, None, None, None, None, None, None, None, None, None, 84.0]
# [None, None, None, None, None, None, None, None, None, None, 70.0]
# [None, None, None, None, None, None, None, None, None, None, 84.0]
# [None, None, None, None, None, None, None, None, None, None, 77.0]
# [None, None, None, None, None, None, None, None, None, None, 60.0]
# [None, None, None, None, None, None, None, None, None, None, 78.5]
# [None, None, None, None, None, None, None, None, None, None, 85.0]
# [None, None, None, None, None, None, None, None, None, None, 60.5]
# [None, None, None, None, None, None, None, None, None, None, 85.75]
# [None, None, None, None, None, None, None, None, None, None, 82.25]
# [None, None, None, None, None, None, None, None, None, None, 75.75]
# [None, None, None, None, None, None, None, None, None, None, 83.0]
# [None, None, None, None, None, None, None, None, None, None, 75.75]
# [None, None, None, None, None, None, None, None, None, None, 61.0]
# [None, None, None, None, None, None, None, None, None, None, 85.5]
# [None, None, None, None, None, None, None, None, None, None, 75.0]
# [None, None, None, None, None, None, None, None, None, None, 83.0]
# [None, None, None, None, None, None, None, None, None, None, 85.0]
# [None, None, None, None, None, None, None, None, None, None, 77.0]
# [None, None, None, None, None, None, None, None, None, None, 79.0]
# [None, None, None, None, None, None, None, None, None, None, 80.25]
# [None, None, None, None, None, None, None, None, None, None, 82.75]
# [None, None, None, None, None, None, None, None, None, None, 67.0]
# [None, None, None, None, None, None, None, None, None, None, 80.5]
# [None, None, None, None, None, None, None, None, None, None, 79.0]
# [None, None, None, None, None, None, None, None, None, None, 85.5]
# [None, None, None, None, None, None, None, None, None, None, 83.75]
# [None, None, None, None, None, None, None, None, None, None, 63.0]
# [None, None, None, None, None, None, None, None, None, None, 83.0]
# [None, None, None, None, None, None, None, None, None, None, 70.25]
# [None, None, None, None, None, None, None, None, None, None, 63.0]
# [None, None, None, None, None, None, None, None, None, None, 84.0]
# [None, None, None, None, None, None, None, None, None, None, 84.5]
# [None, None, None, None, None, None, None, None, None, None, 42.0]
# [None, None, None, None, None, None, None, None, None, None, 83.0]
# [None, None, None, None, None, None, None, None, None, None, 72.0]
# [None, None, None, None, None, None, None, None, None, None, 77.0]
# [None, None, None, None, None, None, None, None, None, None, 75.0]
# [None, None, None, None, None, None, None, None, None, None, 85.75]
# [None, None, None, None, None, None, None, None, None, None, 85.0]
# [None, None, None, None, None, None, None, None, None, None, 79.5]
# [None, None, None, None, None, None, None, None, None, None, 74.0]
# [None, None, None, None, None, None, None, None, None, None, 81.75]
# [None, None, None, None, None, None, None, None, None, None, 73.5]
# [None, None, None, None, None, None, None, None, None, None, 81.0]
# [None, None, None, None, None, None, None, None, None, None, 84.75]
# [None, None, None, None, None, None, None, None, None, None, 64.25]
# [None, None, None, None, None, None, None, None, None, None, 84.0]
# [None, None, None, None, None, None, None, None, None, None, 85.0]
# [None, None, None, None, None, None, None, None, None, None, 79.0]
# [None, None, None, None, None, None, None, None, None, None, 81.0]
# [None, None, None, None, None, None, None, None, None, None, 79.0]
# [None, None, None, None, None, None, None, None, None, None, 82.0]
# [None, None, None, None, None, None, None, None, None, None, 83.0]
# [None, None, None, None, None, None, None, None, None, None, 86.0]
# [None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, 73.0]
# [None, None, None, None, None, None, None, None, None, None, 85.75]
# [None, None, None, None, None, None, None, None, None, None, 83.5]
# [None, None, None, None, None, None, None, None, None, None, 53.0]
# [None, None, None, None, None, None, None, None, None, None, 83.5]
# [None, None, None, None, None, None, None, None, None, None, 79.5]
# [None, None, None, None, None, None, None, None, None, None, 82.25]
# [None, None, None, None, None, None, None, None, None, None, 80.0]
# [None, None, None, None, None, None, None, None, None, None, 87.0]
# [None, None, None, None, None, None, None, None, None, None, 73.0]
# [None, None, None, None, None, None, None, None, None, None, 85.25]
# [None, None, None, None, None, None, None, None, None, None, 86.5]
# [None, None, None, None, None, None, None, None, None, None, 85.5]
# [None, None, None, None, None, None, None, None, None, None, 82.0]
# [None, None, None, None, None, None, None, None, None, None, 71.75]
# [None, None, None, None, None, None, None, None, None, None, 81.25]
# [None, None, None, None, None, None, None, None, None, None, 86.75]
# [None, None, None, None, None, None, None, None, None, None, 83.5]
# [None, None, None, None, None, None, None, None, None, None, 73.25]
# [None, None, None, None, None, None, None, None, None, None, 78.25]
# [None, None, None, None, None, None, None, None, None, None, 84.0]
# [None, None, None, None, None, None, None, None, None, None, 83.0]
# [None, None, None, None, None, None, None, None, None, None, 82.5]
# [None, None, None, None, None, None, None, None, None, None, 80.5]
# [None, None, None, None, None, None, None, None, None, None, 84.25]
# [None, None, None, None, None, None, None, None, None, None, 81.5]
# [None, None, None, None, None, None, None, None, None, None, 86.0]
# [None, None, None, None, None, None, None, None, None, None, 79.0]
# [None, None, None, None, None, None, None, None, None, None, 80.75]
# [None, None, None, None, None, None, None, None, None, None, 86.5]
# AB2-36
# 1735
# 1778
# AB2-17
# AB2-16
# AB2-15
# AB2-14
# AB2-13
# AB2-12
# AB2-11
# AB2-10
# AB2-53
# AB2-52
# AB2-51
# AB2-50
# AB2-57
# AB2-56
# AB2-19
# AB2-18
# 1739
# 1774
# 1777
# 1776
# 1771
# 1770
# 1773
# 1772
# 1731
# 1730
# 1733
# 1732
# 1779
# 1734
# 1737
# 1736
# AB2-45
# AB2-43
# AB2-58
# AB2-62
# AB2-63
# AB2-60
# AB2-61
# AB2-66
# AB2-28
# AB2-64
# AB2-65
# AB2-37
# 1701
# 1702
# 1703
# 1704
# 1705
# 1706
# 1707
# 1708
# 1709
# AB2-24
# AB2-25
# AB2-22
# AB2-23
# AB2-20
# AB2-21
# AB2-26
# AB2-29
# 1748
# 1749
# AB2-27
# 1744
# 1745
# 1746
# 1747
# 1740
# 1741
# 1742
# 1743
# AB2-54
# AB2-59
# AB2-9
# AB2-67
# 1713
# 1712
# 1711
# 1710
# 1717
# 1716
# 1715
# 1714
# AB2-35
# AB2-34
# 1719
# 1718
# AB2-31
# AB2-30
# AB2-33
# AB2-32
# AB2-55
# 1759
# 1758
# 1757
# 1756
# 1755
# 1754
# 1753
# 1752
# 1751
# 1750
# 1775
# AB2-8
# 1738
# AB2-7
# AB2-6
# AB2-5
# AB2-4
# AB2-3
# AB2-2
# AB2-1
# AB2-48
# AB2-49
# AB2-44
# AB2-39
# AB2-46
# AB2-47
# AB2-40
# AB2-41
# AB2-42
# AB2-38
# 1728
# 1729
# 1726
# 1727
# 1724
# 1725
# 1722
# 1723
# 1720
# 1721
# 1768
# 1769
# 1762
# 1763
# 1760
# 1761
# 1766
# 1767
# 1764
# 1765
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'RAM\xd3N PALACIO', '16340538', '', 'LA JULIA', 'LA CRISTALINA']
# ['13.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'HUMBERTO CASTA\xd1O MORENO', '4 586 550', '6668701368', 'EL RECINTO', 'LA LINDA ']
# ['18.06.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ALBERTO DE JESUS PAREJA', '9 955 849', '6668700738', 'EL JORDAN', 'PUEBLO VANO ']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'DIEGO AGUDELO JARAMILLO', '79377077', '6668701281', 'LA POLONIA', 'BUENOS AIRES']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'PEDRO NEL RESTREPO', '9956772', '6668700567', 'LA IBERIA ', 'MAPA']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'MARIA NOHELIA CASTA\xd1O', '25191547', '6668700029', 'EL SOCORRO', 'LA CRISTALINA']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'HUMBERTO CASTA\xd1O MORENO ', '4586550', '6668701368', 'EL RECINTO ', 'LA LINDA ']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'OMAR ZAMORA ARIAS ', '10.192.641', '6668700030', 'ANDA LUCIA ', 'BAJA ESMERALDA']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'GABRIEL ANONIO RESTREPO', '10.194.066', '6668701980', 'LA ESPERANZA', 'ALTO BARCINAL ']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'GUSTAVO DE JESUS LONDO\xd1O', '4.588.227', '6668700166', 'LA CIMA ', 'LA UNION']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'CARLOS ARTURO GAVIRIA', '4.587.607', '6668700258', 'EL MIRADOR ', 'BARCINAL']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'CARLOS ARTURO GAVIRIA', '4587607', '', 'EL MIRADOR ', 'BARCINAL']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'JAVIER ZAMORA', '4587043', '', 'EL PORVENIR', 'LA CRISTALINA']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'GABRIEL ARMANDO GIRALDO', '9957304', '', 'LA MUNERA', 'ALTO PE\xd1AS B']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'ROGELIO ARREDONDO', '4589048', '', 'LA ISLA ', 'LA LINDA ']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'LUZ ELENIS CASTA\xd1O', '9958312', '', 'LA ESPERANZA', 'LA LINDA ']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'ERNESTO JIMENEZ ARANGO', '4586617', '', 'LA ISLA ', 'MAPA']
# ['24.10.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'PEDRO ANTONIO SALAZAR ', '4586274', '6668701635', 'BELLA VISTA ', 'EL CEDRAL']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'FERNEY ANTONIO YEPEZ', '9955346', '6668701013', 'LA MARGARITA', 'EL CEDRAL']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ALBERTO VASQUEZ', '4 588 508', '6668701374', 'EL ESFUERZO', 'LA LINDA ']
# ['04.06.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'NINI JHOANA RAMIREZ', '1 090 148 073', '6668700708', 'LA NUEVA', 'COMINAL']
# ['18.06.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JUAN CARLOS VALERO', '9 956 248', '6668700812', 'EL SANTUARIO', 'EL BRILLANTE']
# ['18.06.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'RUBEN DARIO VELAZQUEZ', '10 194 470', '6668701311', 'EL CANELON', 'LA BOMBA']
# ['18.06.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JOSE EVELIO SALAZAR', '2 653 876', '6668700337', 'BELLA VISTA', 'OROFINO']
# ['04.06.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'HORACIO ANTONIO RAMIREZ', '4 587 888', '6668700388', 'EL DESACUERDO', 'COMINAL']
# ['18.06.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ALBEIRO ANTONIO LOPEZ', '70 000 920', '6668700640', 'EL PORVENIR', 'COMINAL']
# ['18.06.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'GABRIEL RAMIREZ JURADO', '1 410 655', '6668700702', 'EL TESORO', 'COMINAL']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ROGELIO ARREDONDO', '4 589 048', '6668700679', 'LA ISLA ', 'LA LINDA ']
# ['19.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'LIGIA RESTREPO DE HERNANDEZ', '29 456 049', '6668700163', 'SANTA ROSA', 'LA UNION']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ALCIDES LOPEZ', '1 061 624 203', 'NO TIENE FINCA', 'CASA BLANCA', 'BAJO PE\xd1AS B ']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'SARA RAMIREZ', '25 191 636', '6668700101', 'EL TESORITO', 'BAJO BARCINAL']
# ['11.06.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'HECTOR BLANDON RUA', '4 588 277', '6668701524', 'EL PORVENIR', 'BAJA ESMERALDA ']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'OSCAR DARIO AGUDELO', '6 512 693', '666870748', 'ALTO BONITO', 'BUENOS AIRES']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'EUNILVER CASTA\xd1O', '9 957 341', '6668701350', 'EL FUTURO', 'COMINAL']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'FRANCISCO ALEJANDRO OCHOA', '10 005 542', '6668700470', 'SAN JOSE 3', 'CALICHAL']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'JORGE IVAN OCHOA', '94262505', '', 'LA ESPERANZA', 'LA CRISTALINA']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'BERNARDO ECHEVERRI', '71908871', '', 'LA SIRENA', 'NAPOLES']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'OMAR ZAMORA ARIAS ', '10192641', '', 'ANDA LUCIA ', 'BAJA ESMERALDA']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'MARIA NOELIA CALDER\xd3N', '25191547', '', 'LOS ALPES', 'BAJA ESMERALDA']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'BENJAM\xcdN MESA', '1233090', '', 'ALTO DEL LORO', 'CONDINA']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'ISABEL USUGA ', '29309110', '', 'TAMBORAL', 'LA LINDA ']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'SARA RAMIREZ', '25191636', '', 'EL TESORITO', 'BARCINAL']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'RUPERTO P\xc9REZ', '4586048', '', 'LA CEIBA', 'EL BRILLANTE']
# ['24.10.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'HECTOR JARAMILLO BOADA', '8310724', '6668700729', 'ALEGRIAS', 'ALTO PE\xd1AS B']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'JHON FREDY HURTADO', '9957880', '', 'AGUA CLARA', 'ALTO PE\xd1AS B']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'JAIRO NARANJO MONTOYA', '9955425', '', 'LA F\xc9', 'BARCINAL']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'GILDARDO CORREA', '', '  ', 'LA JIRONDA', 'BAJA ESMERALDA']
# ['10.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'EDIER RAMOS MARTINEZ', '9 958 701', '6668700680', 'LA ESPERANZA', 'LA LINDA ']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'MARIA IRENE MARTINEZ', '25 191 279', '6668700795', 'EL VERGEL', 'EL BRILLANTE']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'NORALBA DEL SOCORRO CORDOBA', '25 193 860', '6668700182', 'EL SOCORRO', 'BAJO BARCINAL']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'LUZ MARCELA MONTOYA', '29 897 100', '6668700235', 'LA FORTUNA', 'BAJO PE\xd1AS B ']
# ['07.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'FABIOLA MENA OSPINA', '25 191 309', '6668706196', 'AGUA BONITA', 'LA ESPERANZA']
# ['06.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'LUZ ELENIZ CASTA\xd1O', '1 090 148 345', '6668700683', 'LA ESPERANZA', 'LA LINDA ']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ALBEIRO SOTO HERNANDEZ', '6 275 182', '6668701823', 'NAZARETH', 'OROFINO']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'NOLBERTO MESA BEDOYA', '9 955 961', '6668700353', 'LA MILAGROSA', 'LA UNION']
# ['06.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JHON JAIRO ACEVEDO', '9 957 734', '6668701219', 'LA ESTRELLA', 'LA UNION']
# ['24.10.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'YENNY YEPEZ MONTES', '42027805', '6668700673', 'LA ISLA ', 'LA LINDA ']
# ['24.10.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'MARINO ECHEVERRY CORREA', '4589156', '6668700776', 'PIE DE CUESTA', 'EL YARUMO ']
# ['24.10.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'MIRIAM ARENAS CARMONA', '25194333', '6668700162', 'NARANJAL', 'LA UNION ']
# ['24.10.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'EIBER ELIECER HERRERA', '18532432', '6668700022', 'EL RUBY', 'BAJA ESMERALDA']
# ['24.10.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ALBERTO ARRUBLA CARDENAS', '9955135', '66687001252', 'LOS NARANJOS ', 'BAJO PE\xd1AS B ']
# ['24.10.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'GUILLERMO BEDOYA', '4587147', '6668700674', 'LA HERMINIA', 'ALTO PE\xd1AS B']
# ['24.10.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'MARIA GILMA CORRALES', '25191608', '6668700776', 'LUCES DE BUENOS AIRES', 'BUENOS AIRES']
# ['24.10.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JHON JAIRO CARDONA', '9957544', '6668700469', 'SAN JOSE ', 'CALICHAL']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'HENRY BUSTAMANTE GONZALEZ', '9 957 894', '6668700705', 'EL PARAISO', 'COMINAL']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'FABIO VASQUEZ', '4 588 399', '6668700677', 'LA FLORESTA', 'LA LINDA ']
# ['24.10.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'LUIS ALBERTO ARIAS', '4349676', '6668700317', 'LA MIRANDA', 'OROFINO']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JORGE ALIRIO ESPINOZA', '18 590 715', '6668700321', 'LA ARGELIA', 'BUENOS AIRES']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'LIBARDO ANTONIO PIEDRAHITA', '3 410 201', '6668700129', 'EL REGRESO', 'ALTO BARCINAL ']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'GABRIEL ANTONIO RESTREPO', '10 194 066', '6668701980', 'LA ESPERANZA', 'ALTO BARCINAL ']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'FLOR ELBA VARGAS', '24 539 446', '6668701614', 'BUENA VISTA', 'LOS MANGOS ']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'YULDER YEPEZ MONTES', '10 198 791', '6668700678', 'AGUA BONITA', 'LA LINDA ']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'LUIS EDUARDO JIMENEZ', '4 586 354', '6668701257', 'EL PARAISO', 'BAJO PE\xd1AS B ']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'DANILO DE JESUS AGUDELO', '9 955 857', '6668700409', 'LA ARABIA', 'LA BOMBA']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'AVELINO MENA JIMENEZ', '9 958 451', '6668701881', 'EL GUADUAL', 'LA LINDA ']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'GABRIEL HURTADO', '4586265', '', 'LA ESPERANZA', 'OROFINO']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'ARTURO USUGA SUAREZ ', '3429905', '', 'EL RINCON', 'COMINAL']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'LIGIA RESTREPO HERNANDEZ', '29.456.049', '6668700163', 'SANTA ROSA ', 'LA UNION']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'LIGIA RESTREPO', '29436049', '', 'SANTA ROSA', 'LA UNI\xd3N']
# ['08.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'MIGUEL ANGEL VARGAS', '4 588 517', '6668700373', 'BELLA VISTA', 'CALICHAL']
# ['07.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ELIZABETH ARRUBLA', '43 459 989', '6668700762', 'EL ROSAL', 'BAJO PE\xd1AS B ']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'BERNARDO NARANJO BEDOYA', '1 409 893', '6668700137', 'EL LOTE', 'ALTO BARCINAL ']
# ['17.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'LUIS ALBERTO RAMIREZ', '4 587 618', '6668700869', 'LA ESPERANZA', 'SAN GABRIEL']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JESUS OVIDIO GUZMAN ', '4 588 634', '6668700803', 'EL PORVENIR', 'EL BRILLANTE']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'LUZ EDILIA GUZMAN ', '25 193 360', '6668700363', 'LA ESPERANZA', 'CALICHAL']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JORGE IVAN OCHOA', '94 262 505', '6668700068', 'WALKIDIAS', 'LA CRISTALINA']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'GILBERTO RENDON ', '9 956 363', '6668701686', 'BUENOS AIRES', 'ALTO BARCINAL ']
# ['26.12.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JAVIER JIMENEZ LOAIZA', '9956211', '', 'LA YOLANDA', 'PE\xd1AS BLANCAS']
# ['26.12.2016', 'ALEJANDRO BEDOYA-INNPULSA', ' ', '4588355', '6668700724', 'LA RIVERITA', 'BAJO PE\xd1AS B ']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JUAN BAUTISTA RENDON', '9 955 709', '66687701205', 'EL RINCON', 'ALTO BARCINAL ']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ROBERTO PEREZ MEJIA', '4 589 048', '6668700806', 'LA CEIBA', 'EL BRILLANTE']
# ['24.10.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JAVIER ECHEVERY ', '4587621', '6668700740', 'VILLA OFELIA', 'CONDINA']
# ['24.10.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'RAFAEL PEREZ AMELINEZ', '1409056', '6668701395', 'LA CABA\xd1A', 'ALTO PE\xd1AS B']
# ['27.10.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'CRISANTO RIOS MARQUEZ', '4587091', '6668700709', 'LA COLONIA', 'ALTO PE\xd1AS B']
# ['27.10.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ALBERTO PAREJA', '9955849', '6668700738', 'EL JORDAN', 'PUEBLO VANO']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'LUIS MARIANO ALVAREZ', '4586462', '', 'EL ENCANTO', 'ALTA ESMERALDA']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'MARIA MARLENY CASTRO', '25 192 290', '6668700122', 'LA ESPERANZA', 'ALTO BERCINAL']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'GUSTAVO ORTIZ TORRES', '4 590 862', '6668700694', 'FUENTE HERMOSA', 'LA LINDA ']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'MARTHA CECILIA JIMENEZ', '25 191 678', '6668700825', 'MI CARI\xd1O', 'EL BRILLANTE']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'LUIS GONZALO HERRERA', '3 509 382', '6668700797', 'EL PORVENIR', 'EL BRILLANTE ']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'MARIA ELENA PAREJA', '42 019 908', '6668700516', 'EL MANDARINO ', 'CUNDINA']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'BENANCIO PAREJA', '4 587 207', '6668700505', 'LA SELVA ', 'PUEBLO VANO ']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'BERNARDA ALZATE', '25 191 843', '6668701391', 'LA CHUSPA', 'ALTO PE\xd1AS B']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'HENRY LEIVA', '7 727 111', '666870078', 'LA PRIMAVERA ', 'LA UNION']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JAIME GALLEGO ', '16 208 812', '6668701830', 'EL BOSQUE', 'CALICHAL']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'NELSON RESTREPO ', '16 201 809', '6668700747', 'EL LOTE', 'ALTO PE\xd1AS B']
# ['09.06.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'CRISTOBAL MONTES', '10 070 911', '6668701371', 'LA HALIA', 'COMINAL']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JAIRO ORREGO TAMAYO', '4.589.169', '6668700411', 'LA PRADERA', 'LA PALMA']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JOSE ALFREDO ZAPATA', '9 955 772', '6668700742', 'EL HUBITAL', 'ALTO PE\xd1AS B']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ORLANDO DE JESUS RESTREPO', '4.587.062', '6668700747', 'EL BRILLANTE', 'PE\xd1AS BLACAS']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ABELARDO CORRALES VALENCIA ', '8.267.399', '6668700712', 'EL PORVENIR', 'PE\xd1AS BLACAS']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JOSE BERNARDO BERMUDEZ', '4.587.429', '6668701258', 'LA PALMA', 'BAJO BARCINAL ']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'MARIA CONSUELO RENDON ', '25.193.782', '6668701201', 'EL ROBLAL', 'ALTO BARCINAL ']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ALONSO DE JESUS PATI\xd1O', '2.480.229', '6668700704', 'EL IDILIO', 'COMINAL']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'SILVIO QUICENO RUA ', '4.589.886', '', 'LA CAMELIA', 'COMINAL']
# ['19.09.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'DUVAN VARGAS', '9.955.572', '6668700385', 'LA EVELIA ', 'CALICHAL']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'MARIA LUZ ENITH MONTOYA', '42026905', '', 'LA ESPERANZA', 'EL TOTUI ']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'JOS\xc9 ALFREDO ZAPATA', '9955772', '', 'EL HUBITAL', 'BAJO PE\xd1AS B ']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'ORLANDO ZAPATA', '4588716', '', 'EL SOCORRO', 'LA CRISTALINA']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'MIGUEL ANGEL QUINTERO ALVARES', '6273348', '', 'EL CEDRO', 'BAJA ESMERALDA']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'LUZ MARIELA MONTOYA', '29897100', '', 'LA FORTUNA', 'BAJO PE\xd1AS B ']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'MIGUEL VARGAS', '4588517', '', 'BELLA VISTA', 'CALICHAL']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'MIGUEL ANGEL VARGAS', '4588517', '', 'LA FRONTERA', 'BAJA ESMERALDA']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'JHON JAIRO ACEVEDO', '9957734', '', 'LA ESTRELLA', 'LA UNI\xd3N']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'LIBARDO ANTONIO PIEDRAHITA', '3410201', '', 'EL REGRESO', 'BARCINAL']
# ['20.01.2017', 'ALEJANDRO BEDOYA-INNPULSA', 'HECTOR BLANDON RUA', '4588277', '', 'EL TESORO ', 'BAJA ESMERALDA']
# ['17.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JHON JAIRO ACEVEDO', '9 957 734', '6668701219', 'LA ESTRELLA', 'LA UNION']
# ['18.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JHON JAIRO ACEVEDO', '9 957 734', '6668701220', 'LA ESTRELLA', 'LA UNION']
# ['15.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'EUCARIO LEDESMA BERMUDEZ', '4 589 160', '6668700012', 'RINCON SANTO ', 'BAJA ESMERALDA ']
# ['16.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'CARLOS ALBERTO RESTREPO', '9 957 120', '6668700061', 'EL PORVENIR', 'LA CRISTALINA']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'AUGUSTO RENDON MONCADA ', '4 588 557', '6668700292', 'LA GERMANIA', 'ALTA ESMERALDA']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ISABEL USUGA ', '29 309 110', '6668700667', 'TAMBORAL', 'LA LINDA ']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'MARIO DE JESUS CANO', '9 956 457', '6668700165', 'LA DEVISA', 'LA UNION']
# ['13.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'LUZ INEZ ZAPTA', '25 193 689', '6668700216', 'EL RECREO', 'ALTO PE\xd1AS B']
# ['14.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ORLANDO RESTREPO ', '4 587 062', '66687000746', 'EL BRILLANTE', 'ALTO PE\xd1AS B']
# ['13.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'JOSE DUVAN VARGAS', '9 955 572', '6668700385', 'LA EVELIA', 'CALCHAL']
# ['09.06.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'ALVARO JIMENEZ', '4 589 231', '6668701697', 'EL LOTE', 'BAJO PE\xd1AS B ']
# ['18.06.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'GILDARDO RESTREPO', '9 956 205', '6668700895', 'EL PLACER', 'EL BRILLANTE']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'OMAR HOLGUIN', '4 588 136', '6668700058', 'EL PORVENIR', 'LA CRISTALINA']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'EDUARDO ACEVEDO', '2 471 553', '6668700144', 'BUENOS AIRES', 'ALTO BARCINAL ']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'LUIS MARINO ALVAREZ', '4 586 462', '6668701279', 'EL ENCANTO', 'ALTA ESMERALDA']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'CARLOS ALBERTO AMELINEZ', '9 955 074', '6668700239', 'LA ESTRELLA', 'BAJO PE\xd1AS B ']
# ['09.06.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'RICARDO CASTILLA', '79 149 517', '6668700062', 'LA CABA\xd1A', 'ALTA ESMERALDA']
# ['18.06.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'MIGEL ANGEL ROJAS', '615176', '6668700021', 'LA MERLANDIA ', 'BAJA ESMERALDA ']
# ['28.05.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'SANDRA MILENA MONTOA', '30 391 080', '6668700663', 'EL TESORO', 'COMINAL']
# ['18.06.2016', 'ALEJANDRO BEDOYA-INNPULSA', 'GONZALO COLORADO BENITEZ', '4 588 271', '6668700274', 'BELLA VISTA', 'BUENOS AIRES']
